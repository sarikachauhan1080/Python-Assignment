# %%
# 1. Write a program to add two lists index-wise.
# Create a new list that contains 0th index item from both list,
# then the 1st index item, and so on till the last element.
# any leftover items will get added at the end of the new list.
# 	Given List:
# 	list1 = ["M", "na", "i", "Ra"]
# 	list2 = ["y", "me", "s", "hul"]

# 	Output:

# 	[['M','y'], ['na', me'], ['i', 's'], ['Ra', 'hul']]

list1 = ["M", "na", "i", "Ra"]
list2 = ["y", "me", "s", "hul"]

list3=[]

for i in range(len(list1)):
    list3.append([list1[i],list2[i]])

print(list3)
# Out:
# [['M', 'y'], ['na', 'me'], ['i', 's'], ['Ra', 'hul']]

# %%
# 2. WAP to add item 7000 after 6000 in the following Python List

# 	list1 = [10, 20, [300, 400, [5000, 6000], 500], 30, 40]
# 	Output:


list1=[10, 20, [300, 400, [5000, 6000], 500], 30, 40]

list1[2][2].append(7000)

print(list1)
# Out:
# [10, 20, [300, 400, [5000, 6000, 7000], 500], 30, 40]

# %%
# 3. Suppose you are given a list of candy and another list of same size representing no of items of respective candy.

# 	candy_list = ['Jelly Belly','Kit Kat','Double Bubble','Milky Way','Three Musketeers']
# 	no_of_items = [10,20,34,74,32]
# 	Write a program to show no. of items of each candy type.

# 	Output:

# 	Jelly Belly-10
# 	Kit Kat-20
# 	Double Bubble-34
# 	Milky Way-74
# 	Three Musketeers-32

candy_list = ['Jelly Belly','Kit Kat','Double Bubble','Milky Way','Three Musketeers']
no_of_items = [10,20,34,74,32]

for i in range(len(candy_list)):
    print(candy_list[i],"-",no_of_items[i])
# Out:
# Jelly Belly - 10
# Kit Kat - 20
# Double Bubble - 34
# Milky Way - 74
# Three Musketeers - 32

# %%
# 4. Running Sum on list Write a program to print a list after performing running sum on it.

# 	Input:
# 	list1 = [1,2,3,4,5,6]
# 	Output:

# 	[1,3,6,10,15,21]

list1 = [1,2,3,4,5,6]

result=[]
total = 0

for i in list1:
    total= total + i
    result.append(total)
print(result)
# Out:
# [1, 3, 6, 10, 15, 21]

# %%
# 5. You are given a list of integers.
#    You are asked to make a list by running through elements of the list by adding all elements greater and itself.

# 	i.e. Say given list is [2,4,6,10,1] resultant list will be [22,20,10,23].

# 	For 1st element 2 ->> these are greater (4+6+10) values and 2 itself so on adding becomes 22.

# 	For 2nd element 4 ->> greater elements are (6, 10) and 4 itself, so on adding 20

# 	like wise for all other elememts.

# 	[2,4,6,10,1]-->[22,20,16,10,23]


list1= [2,4,6,10,1]

result=[]

total = 0 #2

for i in list1:
    total=i

    for j in list1:
        if j>i:
            total=total+j

    result.append(total)
    #22,20
print(result)
# Out:
# [22, 20, 16, 10, 23]

# %%
# 6. Find list of common unique items from two list. and show in increasing order

# 	Input

# 	num1 = [23,45,67,78,89,34]
# 	num2 = [34,89,55,56,39,67]
# 	Output:

# 	[34, 67, 89]


num1 = [23,45,67,78,89,34]
num2 = [34,89,55,56,39,67]

result=sorted(set(num1) & set(num2))

print(result)
# Out:
# [34, 67, 89]

# %%
# 7. Sort a list of alphanumeric strings based on product value of numeric character in it.
# If in any string there is no numeric character take it's product value as 1.

# 	Input:

#['1ac21', '23fg', '456', '098d','1','kls']

def get_product(s):
    product = 1  # start with 1 (for multiplication)

    for ch in s:  # go through each character
        if ch.isdigit():  # check if it's a number
            product *= int(ch)  # multiply digit

    return product  # return final product


# input list
lst = ['1ac21', '23fg', '456', '098d', '1', 'kls']


# sort based on product of digits
sorted_list = sorted(lst, key=get_product)


# print result
print(sorted_list)
# Out:
# ['098d', '1', 'kls', '1ac21', '23fg', '456']

# %%
# 8. Write a program that can find the max number of each row of a matrix
# 	Example:
# 	Input:
# 	[[1,2,3],[4,5,6],[7,8,9]]
# 	Output:
# 	[3,6,9]

list= [[1,2,3],[4,5,6],[7,8,9]]

result=[]

for i in list:
    max_value=max(i)
    result.append(max_value)

print(result)
# Out:
# [3, 6, 9]

# %%
# 9. Shortlist Students for a Job role Ask user to input students record and store in tuples for each record.
#    Then Ask user to input three things he wants in the candidate- Primary Skill, Higher Education, Year of Graduation.

# 	Show every students record in form of tuples if matches all required criteria.

# 	It is assumed that there will be only one primry skill.

# 	If no such candidate found, print No such candidate

# 	Input:

# 	Enter No of records- 2
# 	Enter Details of student-1
# 	Enter Student name- Manohar
# 	Enter Higher Education- B.Tech
# 	Enter Primary Skill- Python
# 	Enter Year of Graduation- 2022
# 	Enter Details of student-2
# 	Enter Student name- Ponian
# 	Enter Higher Education- B.Sc.
# 	Enter Primary Skill- C++
# 	Enter Year of Graduation- 2020

# 	Enter Job Role Requirement
# 	Enter Skill- Python
# 	Enter Higher Education- B.Tech
# 	Enter Year of Graduation- 2022
# 	Output

# 	('Manohar', 'B.tech', 'Python', '2022')

n= int(input("Enter how many students record you want :")) # Number of records.

students=[] #using list to store the multiple tuples as once the tuple is created we can't modify it so we will be using list instead and inside tuple to store the data.

for i in range(n):
    print(f"Ente the details of student-{i+1}") #i=0 so this is to ensure that details starts from 1 and not 0

    Name=input("Enter student name:")
    Education=input("Enter Highest education:")
    Skill=input("Enter Primary skill:")
    Year=input("Enter the year of graduation:")

#Storing as tuple
    students.append((Name,Education,Skill,Year))

#Getting the job requirement from user

print("Enter the job role requirement below.")
req_skill=input("Enter skill-")
req_education=input("Enter Highesh Education:")
req_year=input("Enter the year of graduation needed:")

found=False # to check if any match found

#Checking each student for matching data.

for i in students:
    if i[1]==req_education and i[2]== req_skill and i[3]==req_year:
        print(i)
        found=True


#if no match

if not found:
    print("No such candidate")
# Out:
# Enter how many students record you want :2
# Ente the details of student-1
# Enter student name:Sarika
# Enter Highest education:MSC
# Enter Primary skill:SQL
# Enter the year of graduation:2021
# Ente the details of student-2
# Enter student name:Yash
# Enter Highest education:MBA
# Enter Primary skill:Marketing
# Enter the year of graduation:2021
# Enter the job role requirement below.
# Enter skill-Marketing
# Enter Highesh Education:MBA
# Enter the year of graduation needed:2021
# ('Yash', 'MBA', 'Marketing', '2021')

# %%
# 10. Write a program to find set of common elements in three lists using sets.

# 	Input : ar1 = [1, 5, 10, 20, 40, 80]
# 			ar2 = [6, 7, 20, 80, 100]
# 			ar3 = [3, 4, 15, 20, 30, 70, 80, 120]

# 	Output : [80, 20]

ar1 = [1, 5, 10, 20, 40, 80]
ar2 = [6, 7, 20, 80, 100]
ar3 = [3, 4, 15, 20, 30, 70, 80, 120]

s1 = set(ar1)
s2 = set(ar2)
s3 = set(ar3)

result = s1 & s2 & s3

print(list(result))
# Out:
# [80, 20]

# %%
# 11. Write a program to count unique number of vowels using sets in a given string.
#     Lowercase and upercase vowels will be taken as different.
# 	  Input:
# 	  Str1 = "hands-on data science mentorship progrAm with live classes at affordable fee only on CampusX"
# 	 Output:
# 	  No of unique vowels-6

Str1 = "hands-on data science mentorship progrAm with live classes at affordable fee only on CampusX"

count=set() #empty set so no duplicate issue

for i in Str1:
    if i in "aieouAEIOU":
        count.add(i) #add into set


print("Unique vowels are:", count)
print("Count of unique vowels:", len(count))
# Out:
# Unique vowels are: {'a', 'e', 'A', 'o', 'u', 'i'}
# Count of unique vowels: 6

# %%
# 12. Intersection of two lists. Intersection of two list means we need to take all those elements which are common to both of the initial lists and store them into another list. Only use using list-comprehension.
# 	Example 1:

# 	Input:

# 	lst1 = {15, 9, 10, 56, 23, 78, 5, 4, 9}
# 	lst2 = {9, 4, 5, 36, 47, 26, 10, 45, 87}
# 	Output:

# 	[9, 10, 4, 5]
# 	Example 2:

# 	Input:

# 	lst1 = {4, 9, 1, 17, 11, 26, 28, 54, 69}
# 	lst2 = {9, 9, 74, 21, 45, 11, 63, 28, 26}
# 	Output:

# 	[9, 11, 26, 28]



lst1 = {15, 9, 10, 56, 23, 78, 5, 4, 9}
lst2 = {9, 4, 5, 36, 47, 26, 10, 45, 87}

s1=list(lst1)
s2=list(lst2)

result= [x for x in lst1 if x in lst2]

print(result)


lst1 = {4, 9, 1, 17, 11, 26, 28, 54, 69}
lst2 = {9, 9, 74, 21, 45, 11, 63, 28, 26}

s1=list(lst1)
s2=list(lst2)

result= [x for x in lst1 if x in lst2]

print(result)
# Out:
# [4, 5, 9, 10]
# [9, 11, 26, 28]

# %%
# 13. Convert a list of Tuples into Dictionary.
# 	Example 1:

# 	Input:

# 	[("akash", 10), ("gaurav", 12), ("anand", 14), ("suraj", 20), ("akhil", 25), ("ashish", 30)]
# 	Output:

# 	{'akash': [10], 'gaurav': [12], 'anand': [14], 'suraj': [20], 'akhil': [25], 'ashish': [30]}
# 	Example 2:

# 	Input:

# 	[('A', 1), ('B', 2), ('C', 3)]
# 	Output:

# 	{'A': [1], 'B': [2], 'C': [3]}

lst= [("akash", 10), ("gaurav", 12), ("anand", 14), ("suraj", 20), ("akhil", 25), ("ashish", 30)]

result={}

for key,value in lst:
    result[key]=[value]

print(result)
# Out:
# {'akash': [10], 'gaurav': [12], 'anand': [14], 'suraj': [20], 'akhil': [25], 'ashish': [30]}

# %%
# 14. Write a Python function that takes a list and returns a new list with unique elements of the first list.
# 	Exercise 1:

# 	Input:

# 	[1,2,3,3,3,3,4,5]
# 	Output:

# 	[1, 2, 3, 4, 5]


lst=[1,2,3,3,3,3,4,5]

lst1=[]

for i in lst:
    if i not in lst1:
        lst1.append(i)

print(lst1)
# Out:
# [1, 2, 3, 4, 5]

# %%
# 15.  Write a Python program to print the even numbers from a given list.
# 		Sample List : [1, 2, 3, 4, 5, 6, 7, 8, 9]
# 		Expected Result : [2, 4, 6, 8]

lst = [1, 2, 3, 4, 5, 6, 7, 8, 9]

lst1=[]

for i in lst:
    if i%2==0:
        lst1.append(i)

print(lst1)
# Out:
# [2, 4, 6, 8]

# %%
# 16. Write a Python function to check whether a number is perfect or not.¶
# 	A Perfect number is a number that is half the sum of all of its positive divisors (including itself).

# 	Example :

# 	The first perfect number is 6, because 1, 2, and 3 are its proper positive divisors, and 1 + 2 + 3 = 6.
# 	Equivalently, the number 6 is equal to half the sum of all its positive divisors: ( 1 + 2 + 3 + 6 ) / 2 = 6.

# 	The next perfect number is 28 = 1 + 2 + 4 + 7 + 14. This is followed by the perfect numbers 496 and 8128.


def is_perfect(n):
    sum_div = 0   # here we store sum of divisors

    # loop from 1 to n//2 (after that no divisors possible)
    for i in range(1, n//2 + 1):
        if n % i == 0:      # check if i divides n
            sum_div += i    # add divisor to sum

    return sum_div == n     # return True if sum equals n


num = 6   # number we want to check

# function call is happening here
if is_perfect(num):
    print("Perfect Number")
else:
    print("Not Perfect Number")
# Out:
# Perfect Number

# %%
# 17. Write a Python function to concatenate any no of dictionaries to create a new one.
# 	Sample Dictionary :
# 	dic1={1:10, 2:20}
# 	dic2={3:30, 4:40}
# 	dic3={5:50,6:60}
# 	Expected Result : {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60}

dic1={1:10, 2:20}
dic2={3:30, 4:40}
dic3={5:50,6:60}

def concate():
    result={} #created empty dict to store values

    #merging the dicts

    result.update(dic1)
    result.update(dic2)
    result.update(dic3)


    return result           #final result to be returned

output=concate() #function call

print(output)
# Out:
# {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60}

# %%
# 18. Write a python function that receives a list of integers and prints out a histogram of bin size 10

# 	Input:
# 	[13,42,15,37,22,39,41,50]
# 	Output:
# 	{11-20:2,21-30:1,31-40:2,41-50:3}


lst = [13,42,15,37,22,39,41,50]

def histogram(lst):
    b1=b2=b3=b4 = 0

    for i in lst:
        if 11 <= i <= 20:
            b1=b1+1
        elif 21 <= i <= 30:
            b2=b2+1
        elif 31 <= i <= 40:
            b3=b3+1
        elif 41 <= i <= 50:
            b4=b4+1

    print({"11-20":b1,
       "21-30":b2,
       "31-40":b3,
       "41-50":b4})


histogram([13,42,15,37,22,39,41,50])
# Out:
# {'11-20': 2, '21-30': 1, '31-40': 2, '41-50': 3}
